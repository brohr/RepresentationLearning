# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)
# %matplotlib inline

# %%
df = pd.read_csv('alexnet_results.csv')

# %%
layers = df['Layer'].unique()

# %%
pool5 = df[df['Layer'] == 'pool5']

# %%
pool5
# Out:
#      Steps  Layer        IT  Accuracy
# 5    90000  pool5  0.236361      0.49
# 13  150000  pool5  0.216217      0.50
# 21  240000  pool5  0.232098      0.53

# %%
plt.rcParams["figure.figsize"] = (10,10)
for layer in layers:
    dflayer =  df[df['Layer'] == layer]
    plt.plot(dflayer['Accuracy'], dflayer['IT'], marker='o', 
             markersize = 15, alpha=0.5, label=layer)

#plt.xlim(0,0.8)
plt.ylim(0,0.3)
plt.legend(fontsize=16);
plt.ylabel('IT Regression',fontsize=16)
plt.xlabel('Classification Accuracy',fontsize=16)
# Out:
# Text(0.5,0,u'Classification Accuracy')
